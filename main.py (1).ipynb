# %%
@app.get("/hello")
async def hello():
    return "welcome"

# %%
# !pip install fastapi uvicorn nest_asyncio
# Out:
# Requirement already satisfied: fastapi in c:\users\feroz\appdata\local\programs\python\python313\lib\site-packages (0.119.1)
# Requirement already satisfied: uvicorn in c:\users\feroz\appdata\local\programs\python\python313\lib\site-packages (0.38.0)
# Requirement already satisfied: nest_asyncio in c:\users\feroz\appdata\local\programs\python\python313\lib\site-packages (1.6.0)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in c:\users\feroz\appdata\local\programs\python\python313\lib\site-packages (from fastapi) (0.48.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\feroz\appdata\local\programs\python\python313\lib\site-packages (from fastapi) (2.12.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\feroz\appdata\local\programs\python\python313\lib\site-packages (from fastapi) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\feroz\appdata\local\programs\python\python313\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\feroz\appdata\local\programs\python\python313\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\feroz\appdata\local\programs\python\python313\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\feroz\appdata\local\programs\python\python313\lib\site-packages (from starlette<0.49.0,>=0.40.0->fastapi) (4.9.0)
# Requirement already satisfied: idna>=2.8 in c:\users\feroz\appdata\local\programs\python\python313\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.49.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\feroz\appdata\local\programs\python\python313\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.49.0,>=0.40.0->fastapi) (1.3.1)
# Requirement already satisfied: click>=7.0 in c:\users\feroz\appdata\local\programs\python\python313\lib\site-packages (from uvicorn) (8.3.0)
# Requirement already satisfied: h11>=0.8 in c:\users\feroz\appdata\local\programs\python\python313\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: colorama in c:\users\feroz\appdata\local\programs\python\python313\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)

# %%
from fastapi import FastAPI
import nest_asyncio
import uvicorn

app = FastAPI()

@app.get("/hello")
async def hello():
    return "welcome"

# Patch asyncio for Jupyter
nest_asyncio.apply()

config = uvicorn.Config(app=app, host="127.0.0.1", port=8001, log_level="info")
server = uvicorn.Server(config)

import asyncio
asyncio.ensure_future(server.serve())
# Out:
# <Task pending name='Task-1' coro=<Server.serve() running at C:\Users\feroz\AppData\Local\Programs\Python\Python313\Lib\site-packages\uvicorn\server.py:69>>
# INFO:     Started server process [25528]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8001 (Press CTRL+C to quit)

# %%
from fastapi import FastAPI
import nest_asyncio
app = FastAPI()

@app.get("/hello/{name}")
def greet(name: str):
    return {"message": f"Hello, {name}!"}
nest_asyncio.apply()

config = uvicorn.Config(app=app, host="127.0.0.1", port=8000, log_level="info")
server = uvicorn.Server(config)

import asyncio
asyncio.ensure_future(server.serve())
